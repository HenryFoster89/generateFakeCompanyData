# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"data_output\MasterMaterial.csv")

df["markUp"] = round(df["UnitPrice"] / df["UnitCost"],2)

# %%
df
# Out:
#     MaterialID  MaterialName          Category UnitOfMeasure  UnitCost  \
# 0       MAT001    Farmaco_A1        Analgesici       Scatole     37.09
# 1       MAT002    Farmaco_B2        Analgesici       Scatole     34.22
# 2       MAT003    Farmaco_C3  Antiinfiammatori       Scatole     33.66
# 3       MAT004    Farmaco_D4     Antistaminici       Flaconi     31.53
# 4       MAT005    Farmaco_E5   Cardiovascolari    Confezioni     29.46
# ..         ...           ...               ...           ...       ...
# 135     MAT136  Farmaco_F136  Antiinfiammatori       Flaconi     33.49
# 136     MAT137  Farmaco_G137          Vitamine       Blister     23.62
# 137     MAT138  Farmaco_H138          Vitamine       Scatole     36.06
# 138     MAT139  Farmaco_I139  Antiinfiammatori    Confezioni     25.18
# 139     MAT140  Farmaco_J140     Antidiabetici       Flaconi     24.36
#
#     Importance  UnitPrice  markUp
# 0        imp_1     116.46    3.14
# 1        imp_1     105.74    3.09
# ...
